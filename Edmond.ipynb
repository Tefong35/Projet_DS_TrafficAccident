# %% [markdown]
# <a href="https://colab.research.google.com/github/Tefong35/Projet_DS_TrafficAccident/blob/main/Edmond.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Projet_DataScientest/000_df_RAW.csv")
df.head()
# Out:
# <ipython-input-12-b693e29acefb>:2: DtypeWarning: Columns (8,12,27,33,35,36,37,38,40,45,46,50,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/Projet_DataScientest/000_df_RAW.csv")
#         Num_Acc  place  catu  grav  sexe  trajet  secu  locp actp  etatp  ...  \
# 0  200500000001    1.0     1     4     1     1.0  11.0   0.0    0    0.0  ...
# 1  200500000001    1.0     1     3     2     3.0  11.0   0.0    0    0.0  ...
# 2  200500000001    2.0     2     1     1     0.0  11.0   0.0    0    0.0  ...
# 3  200500000001    4.0     2     1     1     0.0  31.0   0.0    0    0.0  ...
# 4  200500000001    5.0     2     1     1     0.0  11.0   0.0    0    0.0  ...
#
#    vosp prof plan  lartpc  larrout  surf  infra  situ  env1  vma
# 0   0.0  1.0  1.0       0       63   1.0    0.0   1.0   0.0  NaN
# 1   0.0  1.0  1.0       0       63   1.0    0.0   1.0   0.0  NaN
# 2   0.0  1.0  1.0       0       63   1.0    0.0   1.0   0.0  NaN
# 3   0.0  1.0  1.0       0       63   1.0    0.0   1.0   0.0  NaN
# 4   0.0  1.0  1.0       0       63   1.0    0.0   1.0   0.0  NaN
#
# [5 rows x 57 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2509726 entries, 0 to 2509725
# Data columns (total 57 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Num_Acc      int64
#  1   place        float64
#  2   catu         int64
#  3   grav         int64
#  4   sexe         int64
#  5   trajet       float64
#  6   secu         float64
#  7   locp         float64
#  8   actp         object
#  9   etatp        float64
#  10  an_nais      float64
#  11  num_veh      object
#  12  id_vehicule  object
#  13  secu1        float64
#  14  secu2        float64
#  15  secu3        float64
#  16  senc         float64
#  17  catv         int64
#  18  occutc       float64
#  19  obs          float64
#  20  obsm         float64
#  21  choc         float64
#  22  manv         float64
#  23  motor        float64
#  24  an           int64
#  25  mois         int64
#  26  jour         int64
#  27  hrmn         object
#  28  lum          int64
#  29  agg          int64
#  30  int          int64
#  31  atm          float64
#  32  col          float64
#  33  com          object
#  34  adr          object
#  35  gps          object
#  36  lat          object
#  37  long         object
#  38  dep          object
#  39  catr         float64
#  40  voie         object
#  41  v1           float64
#  42  v2           object
#  43  circ         float64
#  44  nbv          float64
#  45  pr           object
#  46  pr1          object
#  47  vosp         float64
#  48  prof         float64
#  49  plan         float64
#  50  lartpc       object
#  51  larrout      object
#  52  surf         float64
#  53  infra        float64
#  54  situ         float64
#  55  env1         float64
#  56  vma          float64
# dtypes: float64(30), int64(11), object(16)
# memory usage: 1.1+ GB

# %%
df.isna().sum(axis = 0)*100/len(df)
# Out:
# Num_Acc         0.000000
# place           4.906034
# catu            0.000000
# grav            0.000000
# sexe            0.000000
# trajet          0.019683
# secu           16.897861
# locp            2.245703
# actp            2.249728
# etatp           2.247974
# an_nais         0.218550
# num_veh         0.000000
# id_vehicule    85.354855
# secu1          85.354855
# secu2          85.354855
# secu3          85.354855
# senc            0.013149
# catv            0.000000
# occutc         14.469229
# obs             0.042276
# obsm            0.034067
# choc            0.012113
# manv            0.016416
# motor          85.354855
# an              0.000000
# mois            0.000000
# jour            0.000000
# hrmn            0.000000
# lum             0.000000
# agg             0.000000
# int             0.000000
# atm             0.005937
# col             0.001713
# com             0.000239
# adr            13.694881
# gps            56.305868
# lat            42.469696
# long           42.470094
# dep             0.000000
# catr            0.000080
# voie            8.954603
# v1             56.443771
# v2             95.247051
# circ            0.142207
# nbv             0.248832
# pr             40.667706
# pr1            40.822823
# vosp            0.253135
# prof            0.177031
# plan            0.215402
# lartpc         19.689560
# larrout        10.186610
# surf            0.175597
# infra           0.502047
# situ            0.462481
# env1           15.151893
# vma            85.354855
# dtype: float64

# %%
#calcul du poucentage des valeures maquantes.
per_missing_values =(df.isna().sum()) / (len(df))*100
#lets remove the columns that has 0% (we don't need them in our bar chart)
per_missing_values = per_missing_values[per_missing_values > 0 ]
#sort the dataframe
per_missing_values = per_missing_values.sort_values(ascending=False)
per_missing_values.plot(kind='bar',title='pourcentage des valeurs manquantes du jeu de données',color='#ab6565');

# %%
zone  = df.gps.value_counts()
zone
#zone.plot(kind='barh',xlabel='Nombre d’accident',title='Nombre d’accident en fonction de la zone geografique ',color='#55cddd')
# Out:
# M    1054884
# A      19070
# R      12421
# G       8428
# Y       1765
# 0         17
# S          8
# C          4
# T          4
# P          2
# Name: gps, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
#import pandas as pd
import seaborn as sns
sns.set()
#sns.histplot(df.gps, palette={color: color for color in df['gps'].unique()}) #countplot
#plt.xticks(range(10), ["Métropole","Wallis et Futuna","Antilles","Guyane", "Réunion","St Pierre et Miquelon", "Nouvelle Calédonie", "Polynésie française", "Terres austr. et antarct. Françaises", " Mayotte"])
#df['score']=df['score'].astype(float)
zone.plot(kind='barh',xlabel='Nombre d’accident',ylabel='zone géographique', title='Nombre d’accident en fonction de la zone géographique',color='#55cddd');

# %%
Catégorie_de_route = df.catr.value_counts()
Catégorie_de_route
# Out:
# 4.0    1169935
# 3.0     826731
# 1.0     229036
# 2.0     213233
# 9.0      38761
# 6.0      16033
# 7.0      12061
# 5.0       3934
# Name: catr, dtype: int64

# %%
Catégorie_de_route.plot(kind='barh',xlabel='Nombre d’accident',ylabel='Catégorie de route', title='Nombre d’accident en fonction de la Catégorie de route',color='#55cddd');

# %%
df.grav.value_counts()
# Out:
#  1    1029136
#  4     911885
#  3     501566
#  2      67079
# -1         60
# Name: grav, dtype: int64

# %%
#Nous constatons qu'il y'a plus d'accident en métropole (M)
# visualiser en fonction du mois
M_accident = df[df.gps == 'M']
# Group the data by months and calculate the total severity number
grouped_M_accident = M_accident.groupby(M_accident['mois']).agg({'grav':'sum'})
# Convert the index column (months) to a list
Mois = grouped_M_accident.index.tolist()

# Get the severity values as a separate array
grav_values = grouped_M_accident['grav']
# Plot the bar chart
plt.bar(Mois, grav_values,color='#a55ddd')
plt.xlabel('Mois')
plt.ylabel('Total grav')
plt.xticks(Mois)
plt.title('Accident en Métropole en fonction du mois')
plt.show()

# %%
# conditions d’éclairage dans lesquelles l'accident s'est produit.
df.lum.value_counts()
# Out:
#  1    1725649
#  5     402457
#  3     212285
#  2     148754
#  4      20575
# -1          6
# Name: lum, dtype: int64

# %%
Plein_jour = len(df[df.lum == 1])
Crépuscule_aube = len(df[df.lum == 2])
Nuit_sans_éclairage_public = len(df[df.lum == 3])
Nuit_avec_éclairage_public_non_allumé  = len(df[df.lum == 4])
Nuit_avec_éclairage_public_allumé  = len(df[df.lum == 5])
valuer_a = len(df[df.lum == -1])
values=[Plein_jour,Crépuscule_aube,Nuit_sans_éclairage_public,Nuit_avec_éclairage_public_non_allumé, Nuit_avec_éclairage_public_allumé, valuer_a]
labels=[1,2,3,4,5,-1]
colors = ['#ff9999', '#66b3ff', '#ff9999', '#99ff99', '#ffcc99', '#66b3ff']
plt.pie(values,labels=labels,autopct='%1.1f%%',explode=(0.08,0,0,0,0,0),shadow=True,colors=colors)
plt.show()
